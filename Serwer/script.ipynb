-- %% [markdown]
-- # [ZadanieRekrutacyjne]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ZadanieRekrutacyjne]    Script Date: 25.04.2021 18:56:28 ******/
CREATE DATABASE [ZadanieRekrutacyjne]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ZadanieRekrutacyjne', FILENAME = N'E:\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\ZadanieRekrutacyjne.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ZadanieRekrutacyjne_log', FILENAME = N'E:\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\ZadanieRekrutacyjne_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ZadanieRekrutacyjne].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET ARITHABORT OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET RECOVERY FULL 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET  MULTI_USER 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'ZadanieRekrutacyjne', N'ON'
GO
ALTER DATABASE [ZadanieRekrutacyjne] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Permissions]

-- %%
USE [ZadanieRekrutacyjne]
GO

-- %%
/****** Object:  Table [dbo].[Permissions]    Script Date: 25.04.2021 18:56:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Permissions](
	[PermissionID] [int] IDENTITY(1,1) NOT NULL,
	[PermissionCode] [varchar](50) NULL,
	[PermissionName] [varchar](50) NULL,
 CONSTRAINT [PK_Permissions] PRIMARY KEY CLUSTERED 
(
	[PermissionID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserPermission]

-- %%
/****** Object:  Table [dbo].[UserPermission]    Script Date: 25.04.2021 18:56:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserPermission](
	[UserPermissionID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [int] NULL,
	[PermissionID] [int] NULL,
 CONSTRAINT [PK_UserPermission] PRIMARY KEY CLUSTERED 
(
	[UserPermissionID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 25.04.2021 18:56:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserId] [int] IDENTITY(1,1) NOT NULL,
	[Login] [varchar](50) NOT NULL,
	[Password] [varchar](max) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[LastName] [varchar](50) NOT NULL,
	[PESEL] [varchar](11) NOT NULL,
	[DateOfBirth] [date] NULL,
	[PlaceOfBirth] [varchar](50) NULL,
	[Position] [varchar](50) NULL,
 CONSTRAINT [PK_Users] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Permissions]

-- %%
SET IDENTITY_INSERT [dbo].[Permissions] ON 
INSERT [dbo].[Permissions] ([PermissionID], [PermissionCode], [PermissionName]) VALUES (1, N'U-1', N'Administracja')
INSERT [dbo].[Permissions] ([PermissionID], [PermissionCode], [PermissionName]) VALUES (2, N'U-2', N'Dostęp do archiwum')
INSERT [dbo].[Permissions] ([PermissionID], [PermissionCode], [PermissionName]) VALUES (3, N'U-3', N'Dostęp do kartotek')
INSERT [dbo].[Permissions] ([PermissionID], [PermissionCode], [PermissionName]) VALUES (4, N'U-4', N'Dostęp do parametrów')
SET IDENTITY_INSERT [dbo].[Permissions] OFF
GO

-- %% [markdown]
-- # [dbo].[UserPermission]

-- %%
SET IDENTITY_INSERT [dbo].[UserPermission] ON 
INSERT [dbo].[UserPermission] ([UserPermissionID], [UserID], [PermissionID]) VALUES (2, 33, 1)
INSERT [dbo].[UserPermission] ([UserPermissionID], [UserID], [PermissionID]) VALUES (3, 33, 2)
INSERT [dbo].[UserPermission] ([UserPermissionID], [UserID], [PermissionID]) VALUES (4, 33, 3)
INSERT [dbo].[UserPermission] ([UserPermissionID], [UserID], [PermissionID]) VALUES (5, 33, 4)
INSERT [dbo].[UserPermission] ([UserPermissionID], [UserID], [PermissionID]) VALUES (6, 34, 3)
INSERT [dbo].[UserPermission] ([UserPermissionID], [UserID], [PermissionID]) VALUES (7, 34, 2)
SET IDENTITY_INSERT [dbo].[UserPermission] OFF
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
SET IDENTITY_INSERT [dbo].[Users] ON 
INSERT [dbo].[Users] ([UserId], [Login], [Password], [FirstName], [LastName], [PESEL], [DateOfBirth], [PlaceOfBirth], [Position]) VALUES (33, N'Robert88', N'5c80565db6f29da0b01aa12522c37b32f121cbe47a861ef7f006cb22922dffa1', N'Robert', N'Kowalski', N'88050865492', CAST(N'1988-05-08' AS Date), N'Warszawa', N'Administrator')
INSERT [dbo].[Users] ([UserId], [Login], [Password], [FirstName], [LastName], [PESEL], [DateOfBirth], [PlaceOfBirth], [Position]) VALUES (34, N'Mikro', N'9a900403ac313ba27a1bc81f0932652b8020dac92c234d98fa0b06bf0040ecfd', N'Julia', N'Nowak', N'95112508745', CAST(N'1995-11-25' AS Date), N'Wrocław', N'Księgowa')
SET IDENTITY_INSERT [dbo].[Users] OFF
GO

-- %% [markdown]
-- # [UK_Users.Login]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UK_Users.Login]    Script Date: 25.04.2021 18:56:28 ******/
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [UK_Users.Login] UNIQUE NONCLUSTERED 
(
	[Login] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UK_Users.PESEL]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UK_Users.PESEL]    Script Date: 25.04.2021 18:56:28 ******/
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [UK_Users.PESEL] UNIQUE NONCLUSTERED 
(
	[PESEL] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Permission_UserPermission]

-- %%
ALTER TABLE [dbo].[UserPermission]  WITH CHECK ADD  CONSTRAINT [FK_Permission_UserPermission] FOREIGN KEY([PermissionID])
REFERENCES [dbo].[Permissions] ([PermissionID])
GO
ALTER TABLE [dbo].[UserPermission] CHECK CONSTRAINT [FK_Permission_UserPermission]
GO

-- %% [markdown]
-- # [FK_User_UserPermission]

-- %%
ALTER TABLE [dbo].[UserPermission]  WITH CHECK ADD  CONSTRAINT [FK_User_UserPermission] FOREIGN KEY([UserID])
REFERENCES [dbo].[Users] ([UserId])
GO
ALTER TABLE [dbo].[UserPermission] CHECK CONSTRAINT [FK_User_UserPermission]
GO

-- %% [markdown]
-- # [ZadanieRekrutacyjne]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ZadanieRekrutacyjne] SET  READ_WRITE 
GO
